# %%
def get_jobinfo_from_browser(url):
    time.sleep(2)
    job = []
    for session in browser.find_elements_by_css_selector('.job-list ul li'):
        data = {}
        data['Job Title'] = session.find_element_by_css_selector(".job-title").text
        data['Company'] = session.find_element_by_css_selector(".company-text").text
        job.append(data)
    return job


from selenium import webdriver
import time

url = 'https://www.zhipin.com/c101280600/d_203-e_102/?page=1&ka=page-1'
browser = webdriver.Chrome()
browser.get(url)

get_job2 = get_jobinfo_from_browser(browser)
get_job2
import pandas as pd 
df2 = pd.DataFrame(get_job2)
df2[:12]


all_info = []
# 因为一共只有 10 页！！ 智联招聘 + 深圳 + 应届生 + 本科学历 
for i in range(0,9): 
    time.sleep(2) 
    all_info.extend(get_jobinfo_from_browser(url))
    element = browser.find_element_by_class_name("next")
    time.sleep(1)
    loc = element.location
    browser.execute_script("window.scrollTo({x}, {y});".format(**loc))
    element.click()
    time.sleep(1)
all_info
keys = all_info[0].keys()
import csv
import pandas as pd 
with open('智联招聘 + 深圳 + 应届生 + 本科学历.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_info)
    
# 智联招聘 + 深圳 + 研究生 + 本科学历  
url2 = 'https://www.zhipin.com/c101280600/d_204-e_102/?ka=sel-degree-204'
all_info2 = []
for i in range(0,9): 
    time.sleep(2) 
    all_info2.extend(get_jobinfo_from_browser(url))
    element = browser.find_element_by_class_name("next")
    time.sleep(1)
    loc = element.location
    browser.execute_script("window.scrollTo({x}, {y});".format(**loc))
    element.click()
    time.sleep(1)
all_info2
keys = all_info2[0].keys()
import csv
import pandas as pd 
with open('智联招聘 + 深圳 + 应届生 + 研究生学历.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_info)
